# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:\\Users\\Welcome\\Downloads\\2. Cars Data1.csv")

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2    NaN             NaN  Sedan   Asia      Front       NaN  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         NaN        NaN       200.0       NaN         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
print("The size of the data is :",data.size)
print("The shape of the data is :",data.shape,"    i.e in (row,col)")
# Out:
# The size of the data is : 6480
# The shape of the data is : (432, 15)     i.e in (row,col)

# %%
#to find the null value in the data set
data.isnull()
#or
#data.notnull()
# Out:
#       Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0    False  False  False   False       False  False    False       False
# 1    False  False  False   False       False  False    False       False
# 2     True   True  False   False       False   True    False        True
# 3    False  False  False   False       False  False    False       False
# 4    False  False  False   False       False  False    False       False
# ..     ...    ...    ...     ...         ...    ...      ...         ...
# 427  False  False  False   False       False  False    False       False
# 428  False  False  False   False       False  False    False       False
# 429  False  False  False   False       False  False    False       False
# 430  False  False  False   False       False  False    False       False
# 431  False  False  False   False       False  False    False       False
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %% [markdown]
# <h1>Cleaning the data</h1>

# %%
#to find the no. of null value in data
data.isnull().sum()
# Out:
# Make           5
# Model          5
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           5
# Invoice        4
# EngineSize     5
# Cylinders      7
# Horsepower     4
# MPG_City       5
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data["Make"].fillna(data["Make"]=="Acura")
# Out:
# 0      Acura
# 1      Acura
# 2      False
# 3      Acura
# 4      Acura
#        ...
# 427    Volvo
# 428    Volvo
# 429    Volvo
# 430    Volvo
# 431    Volvo
# Name: Make, Length: 432, dtype: object

# %%
data.isna().sum()
# Out:
# Make           5
# Model          5
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           5
# Invoice        4
# EngineSize     5
# Cylinders      7
# Horsepower     4
# MPG_City       5
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
#data['Cylinders'].fillna(data['Cylinders'].mean(),inplace=True)

# %%
print("The total no. of missing values are: ",data.isnull().sum().sum())
# Out:
# The total no. of missing values are:  68

# %% [markdown]
# <b>#Filling the NUll values with zero</b>

# %%
data_zero=data.fillna(value=0)

# %%
data_zero
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2        0                        0  Sedan    Asia      Front         0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data_zero.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# <b>#Filling Null  values with previous value</b>

# %%
data_prev_val=data.fillna(method='pad')
data_prev_val
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data_prev_val.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# <b>Filling the data with upcoming value</b>

# %%
data_next_val=data.fillna(method='bfill')

# %%
data_next_val
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# <b>#filling null value with previous column value

# %%
data_prev_col=data.fillna(method="pad",axis=1)

# %%
data_prev_col
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2      NaN                      NaN  Sedan    Asia      Front     Front
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders Horsepower MPG_City MPG_Highway  Weight  \
# ...

# %% [markdown]
# <b>#filling null value with upcoming column value

# %%
data_replace_upcom=data.fillna(method="bfill",axis=1)

# %%
data_replace_upcom
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Sedan                    Sedan  Sedan    Asia      Front  $24,647
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice EngineSize Cylinders Horsepower MPG_City MPG_Highway  Weight  \
# ...

# %% [markdown]
# <b>#filling different values in null in different columns

# %%
data_fill_na=data.fillna({"Make":"BMW","Model":"q7"})

# %%
data_fill_na
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2      BMW                       q7  Sedan    Asia      Front       NaN
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# <b>#filling with it's mean of the col

# %%
data_replace_mean=data.fillna(value=data["Cylinders"].mean())

# %%
data_replace_mean=data.fillna(value=data["EngineSize"].mean())

# %%
data_replace_mean
# Out:
#          Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0       Acura                      MDX    SUV    Asia        All  $36,945
# 1       Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    3.198595                 3.198595  Sedan    Asia      Front  3.198595
# 3       Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4       Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..        ...                      ...    ...     ...        ...       ...
# 427     Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428     Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429     Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430     Volvo                      V40  Wagon  Europe      Front  $26,135
# 431     Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower   MPG_City  MPG_Highway  \
# ...

# %%
data_replace_mean=data.fillna(value=data["Cylinders"].min())
data_replace_mean=data.fillna(value=data["Cylinders"].max())

# %% [markdown]
# <br><B>#DROPNA</b></br>
#     this function drops the every rows which which contains any null value in it

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2    NaN             NaN  Sedan   Asia      Front       NaN  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         NaN        NaN       200.0       NaN         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data_drop=data.dropna()

# %%
data_drop
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df_drop_how=data.dropna(how='all') 
print("this all condition removes the row only if all the value of row contains null\n If there was any instead of all then it would have reomve the row  if any of the data was missing in the row")
# Out:
# this all condition removes the row only if all the value of row contains null
#  If there was any instead of all then it would have reomve the row  if any of the data was missing in the row

# %%
df_drop_how
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2      NaN                      NaN  Sedan    Asia      Front       NaN
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# <b>#RELACE

# %%
data_replace=data.replace(np.nan,value="missing_val")

# %%
data_replace
# Out:
#             Make                    Model   Type  Origin DriveTrain  \
# 0          Acura                      MDX    SUV    Asia        All
# 1          Acura           RSX Type S 2dr  Sedan    Asia      Front
# 2    missing_val              missing_val  Sedan    Asia      Front
# 3          Acura                   TL 4dr  Sedan    Asia      Front
# 4          Acura               3.5 RL 4dr  Sedan    Asia      Front
# ..           ...                      ...    ...     ...        ...
# 427        Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front
# 428        Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front
# 429        Volvo               S80 T6 4dr  Sedan  Europe      Front
# 430        Volvo                      V40  Wagon  Europe      Front
# 431        Volvo                     XC70  Wagon  Europe        All
#
#             MSRP   Invoice   EngineSize    Cylinders Horsepower     MPG_City  \
# ...

# %%
data_replace=data.replace("Acura","BMW")

# %%
data_replace
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0      BMW                      MDX    SUV    Asia        All  $36,945
# 1      BMW           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2      NaN                      NaN  Sedan    Asia      Front       NaN
# 3      BMW                   TL 4dr  Sedan    Asia      Front  $33,195
# 4      BMW               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# <b>#INTERPOLATE()

# %%
data["Cylinders"]=data["Cylinders"].interpolate(method='linear',limit_direction="forward")
data["EngineSize"]=data["EngineSize"].interpolate(method='linear',limit_direction="forward")

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2      NaN                      NaN  Sedan    Asia      Front       NaN
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Make           5
# Model          5
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           5
# Invoice        4
# EngineSize     0
# Cylinders      0
# Horsepower     4
# MPG_City       5
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data["Horsepower"]=data["Horsepower"].interpolate(method='linear',limt_direction="forward")
data["MPG_City"]=data["MPG_City"].interpolate(method='linear',limt_direction="forward")
data["Weight"]=data["Weight"].interpolate(method='linear',limt_direction="forward")
data["Wheelbase"]=data["Wheelbase"].interpolate(method='linear',limt_direction="forward")
data["Length"]=data["Length"].interpolate(method='linear',limit_direction="forward")
data["MPG_Highway"]=data["MPG_Highway"].interpolate(method='linear',liner_direction="forward")

# %%
data.isnull().sum()
# Out:
# Make           5
# Model          5
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           5
# Invoice        4
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
data=data.replace(method='pad')

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
data['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              22
# Audi             19
# Honda            18
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Hyundai          13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# <b><br>isin(['things_to_be_searched'])</br>

# %% [markdown]
# to show the origin only from Asia and Europe

# %%
data[data["Origin"].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# to show all the weight records that are more than 4000

# %%
data[data["Weight"]>4000]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %% [markdown]
# increase all the values of "MPG_City" column by 3

# %%
data["MPG_City"]=data["MPG_City"].apply(lambda x:x+3)
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
